# %%
# Import Dependencies
import pandas as pd
from pathlib import Path

# %%
csv_path= Path("Resources/2023_national_park_public_data.csv")

national_parks_complete_df= pd.read_csv(csv_path)

national_parks_complete_df.head()
# Out:
#     ParkName UnitCode       ParkType      Region State  Year  Month  \
# 0  Acadia NP     ACAD  National Park  Northeast     ME  2023      1
# 1  Acadia NP     ACAD  National Park  Northeast     ME  2023      2
# 2  Acadia NP     ACAD  National Park  Northeast     ME  2023      3
# 3  Acadia NP     ACAD  National Park  Northeast     ME  2023      4
# 4  Acadia NP     ACAD  National Park  Northeast     ME  2023      5
#
#   RecreationVisits NonRecreationVisits RecreationHours  ...  \
# 0           15,217                 600         100,434  ...
# 1           15,281                 600         100,853  ...
# 2           30,822                 600         203,428  ...
# 3          102,928                 600         596,982  ...
# 4          340,425               7,500       2,369,803  ...
#
#   NonRecreationVisitsTotal RecreationHoursTotal NonRecreationHoursTotal  \
# 0                   47,100           25,804,425                  47,100
# 1                   47,100           25,804,425                  47,100
# 2                   47,100           25,804,425                  47,100
# 3                   47,100           25,804,425                  47,100
# 4                   47,100           25,804,425                  47,100
#
#   ConcessionerLodgingTotal ConcessionerCampingTotal TentCampersTotal  \
# 0                        0                    1,603          120,615
# 1                        0                    1,603          120,615
# 2                        0                    1,603          120,615
# 3                        0                    1,603          120,615
# 4                        0                    1,603          120,615
#
#   RVCampersTotal BackcountryTotal NonRecreationOvernightStaysTotal  \
# 0         49,074            1,570                                0
# 1         49,074            1,570                                0
# 2         49,074            1,570                                0
# 3         49,074            1,570                                0
# 4         49,074            1,570                                0
#
#   MiscellaneousOvernightStaysTotal
# 0                            9,600
# 1                            9,600
# 2                            9,600
# 3                            9,600
# 4                            9,600
#
# [5 rows x 35 columns]

# %%
# Remove unnecessary columns from the DataFrame and save the new DataFrame
national_parks_reduced_df=national_parks_complete_df[["ParkName","Region", "State","Month","RecreationVisits","RecreationHours","RecreationHoursTotal"]]

national_parks_reduced_df.head()
# Out:
#     ParkName      Region State  Month RecreationVisits RecreationHours  \
# 0  Acadia NP  Northeast     ME      1           15,217         100,434
# 1  Acadia NP  Northeast     ME      2           15,281         100,853
# 2  Acadia NP  Northeast     ME      3           30,822         203,428
# 3  Acadia NP  Northeast     ME      4          102,928         596,982
# 4  Acadia NP  Northeast     ME      5          340,425       2,369,803
#
#   RecreationHoursTotal
# 0           25,804,425
# 1           25,804,425
# 2           25,804,425
# 3           25,804,425
# 4           25,804,425

# %%
# Rename headers
national_parks_headers_renamed_df= national_parks_reduced_df.rename(columns={"ParkName":"Park Name",
                                                                    "RecreationVisits":"Recreation Visits by Month",
                                                                    "RecreationHours":"Recreation Hours by Month",
                                                                    "RecreationHoursTotal":"Total Recreation Hours"})

national_parks_headers_renamed_df.head()
# Out:
#    Park Name      Region State  Month Recreation Visits by Month  \
# 0  Acadia NP  Northeast     ME      1                     15,217
# 1  Acadia NP  Northeast     ME      2                     15,281
# 2  Acadia NP  Northeast     ME      3                     30,822
# 3  Acadia NP  Northeast     ME      4                    102,928
# 4  Acadia NP  Northeast     ME      5                    340,425
#
#   Recreation Hours by Month Total Recreation Hours
# 0                   100,434             25,804,425
# 1                   100,853             25,804,425
# 2                   203,428             25,804,425
# 3                   596,982             25,804,425
# 4                 2,369,803             25,804,425

# %%
national_parks_rows_renamed_df=national_parks_headers_renamed_df.replace({"Acadia NP":"Acadia",
                                                                          "Arches NPA":"Arches",
                                                                          "Badlands NP":"Badlands",
                                                                          "Big Bend NP":"Big Bend",
                                                                          "Biscayne NP":"Biscayne",
                                                                          "Black Canyon of the Gunnison NP":"Black Canyon of the Gunnison",
                                                                          "Bryce Canyon NP":"Bryce Canyon",
                                                                          "Canyonlands NP":"Canyonlands",
                                                                          "Capitol Reef NP":"Capitol Reef",
                                                                          "Carlsbad Caverns NP":"Carlsbad Caverns",
                                                                          "Channel Islands NP":"Channel Islands",
                                                                          "Congaree NP":"Congaree",
                                                                          "Crater Lake NP":"Crater Lake",
                                                                          "Cuyahoga Valley NP":"Cuyahoga Valley",
                                                                          "Death Valley NP":"Death Valley",
                                                                          "Denali NP":"Denali",
                                                                          "Dry Tortugas NP":"Dry Tortugas",
                                                                          "Everglades NP":"Everglades",
                                                                          "Gates of the Arctic NP":"Gates of the Arctic",
                                                                          "Gateway Arch NP":"Gateway Arch",
                                                                          "Glacier Bay NP":"Glacier Bay",
                                                                          "Glacier NP":"Glacier",
                                                                          "Grand Canyon NP":"Grand Canyon",
                                                                          "Grand Teton NP":"Grand Teton",
                                                                          "Great Basin NP":"Great Basin",
                                                                          "Great Sand Dunes NP":"Great Sand Dunes",
                                                                          "Great Smoky Mountains NP":"Great Smoky Mountains",
                                                                          "Guadalupe Mountains NP":"Guadalupe Mountains",
                                                                          "Haleakala NP":"Haleakala",
                                                                          "Hawaii Volcanoes NP":"Hawaii Volcanoes",
                                                                          "Hot Springs NP":"Hot Springs",
                                                                          "Indiana Dunes NP":"Indiana Dunes",
                                                                          "Isle Royale NP":"Isle Royale",
                                                                          "Joshua Tree NP":"Joshua Tree",
                                                                          "Katmai NP":"Katmai",
                                                                          "Kenai Fjords NP":"Kenai Fjords",
                                                                          "Kings Canyon NP":"Kings Canyon",
                                                                          "Kobuk Valley NP":"Kobuk Valley",
                                                                          "Lake Clark NP":"Lake Clark",
                                                                          "Lassen Volcanic NP":"Lassen Volcanic",
                                                                          "Mammoth Cave NP":"Mammoth Cave",
                                                                          "Mesa Verde NP":"Mesa Verde",
                                                                          "Mount Rainier NP":"Mount Rainier",
                                                                          "New River Gorge NP":"New River Gorge",
                                                                          "North Cascades NP":"North Cascades",
                                                                          "Olympic NP":"Olympic",
                                                                          "Petrified Forest NP":"Petrified Forest",
                                                                          "Pinnacles NP":"Pinnacles",
                                                                          "Redwood NP":"Redwood",
                                                                          "Rocky Mountain NP":"Rocky Mountain",
                                                                          "Saguaro NP":"Saguaro",
                                                                          "Sequoia NP":"Sequoia",
                                                                          "Shenandoah NP":"Shenandoah",
                                                                          "Theodore Roosevelt NP":"Theodore Roosevelt",
                                                                          "Virgin Islands NP":"Virgin Islands",
                                                                          "Voyageurs NP":"Voyageurs",
                                                                          "White Sands NP":"White Sands",
                                                                          "Wind Cave NP":"Wind Cave",
                                                                          "Wrangell-St. Elias NP":"Wrangell-St. Elias",
                                                                          "Yellowstone NP":"Yellowstone",
                                                                          "Yosemite NP":"Yosemite",
                                                                          "Zion NP":"Zion",})
national_parks_rows_renamed_df.head()
# Out:
#   Park Name      Region State  Month Recreation Visits by Month  \
# 0    Acadia  Northeast     ME      1                     15,217
# 1    Acadia  Northeast     ME      2                     15,281
# 2    Acadia  Northeast     ME      3                     30,822
# 3    Acadia  Northeast     ME      4                    102,928
# 4    Acadia  Northeast     ME      5                    340,425
#
#   Recreation Hours by Month Total Recreation Hours
# 0                   100,434             25,804,425
# 1                   100,853             25,804,425
# 2                   203,428             25,804,425
# 3                   596,982             25,804,425
# 4                 2,369,803             25,804,425
